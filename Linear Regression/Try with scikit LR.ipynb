# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
crashtypes = pd.read_csv("workvoltwoaa.csv")
crashtypes
# Out:
#        StateFormated  DateFormated  TimeFormated  Crash_TypeFormated  \
# 0                  4         42736          2.00                   2
# 1                  8         42736          0.69                   3
# 2                  8         42736          0.72                   3
# 3                  2         42737          0.76                   3
# 4                  2         42737          0.55                   1
# 5                  4         42737          0.13                   2
# 6                  8         42737          0.77                   3
# 7                  2         42738          0.59                   1
# 8                  2         42738          0.59                   1
# 9                  4         42738          0.67                   1
# 10                 8         42738          0.64                   3
# 11                 4         42739          0.79                   1
# 12                 2         42740          0.43                   2
# ...

# %%
crashtypes.head()
# Out:
#    StateFormated  DateFormated  TimeFormated  Crash_TypeFormated  \
# 0              4         42736          2.00                   2
# 1              8         42736          0.69                   3
# 2              8         42736          0.72                   3
# 3              2         42737          0.76                   3
# 4              2         42737          0.55                   1
#
#    Bus_InvolvementFormated  Heavy_Rigid_Truck_InvolvementFormated  \
# 0                        1                                      1
# 1                        1                                      1
# 2                        1                                      1
# 3                        1                                      1
# 4                        1                                      1
#
#    Speed_LimitFormated  Road_UserFormated  GenderFormated  AgeFormated
# 0                   50                  7               1           64
# ...

# %%
crashtypes.describe()
# Out:
#        StateFormated  DateFormated  TimeFormated  Crash_TypeFormated  \
# count   48365.000000  48365.000000  48365.000000        48365.000000
# mean        4.590985  37148.032689      0.545540            1.993446
# std         2.248999   3018.503531      0.272331            0.917295
# min         1.000000  32509.000000      0.000000            1.000000
# 25%         2.000000  34515.000000      0.340000            1.000000
# 50%         4.000000  36890.000000      0.580000            2.000000
# 75%         7.000000  39611.000000      0.750000            3.000000
# max         8.000000  43039.000000      2.000000            3.000000
#
#        Bus_InvolvementFormated  Heavy_Rigid_Truck_InvolvementFormated  \
# count             48365.000000                           48365.000000
# mean                  1.021503                               2.134539
# std                   0.153908                               0.977071
# ...

# %%
crashtypes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48365 entries, 0 to 48364
# Data columns (total 10 columns):
# StateFormated                            48365 non-null int64
# DateFormated                             48365 non-null int64
# TimeFormated                             48365 non-null float64
# Crash_TypeFormated                       48365 non-null int64
# Bus_InvolvementFormated                  48365 non-null int64
# Heavy_Rigid_Truck_InvolvementFormated    48365 non-null int64
# Speed_LimitFormated                      48365 non-null int64
# Road_UserFormated                        48365 non-null int64
# GenderFormated                           48365 non-null int64
# AgeFormated                              48365 non-null int64
# dtypes: float64(1), int64(9)
# memory usage: 3.7 MB

# %%
sns.jointplot(data=crashtypes,x='TimeFormated',y='Crash_TypeFormated')

# %%
sns.jointplot( x='Crash_TypeFormated', y='AgeFormated', kind ='hex', data=crashtypes)

# %%
sns.pairplot(crashtypes)

# %%
sns.lmplot(x='Crash_TypeFormated',y='Bus_InvolvementFormated', data=crashtypes)

# %%
crashtypes.columns
# Out:
# Index(['StateFormated', 'DateFormated', 'TimeFormated', 'Crash_TypeFormated',
#        'Bus_InvolvementFormated', 'Heavy_Rigid_Truck_InvolvementFormated',
#        'Speed_LimitFormated', 'Road_UserFormated', 'GenderFormated',
#        'AgeFormated'],
#       dtype='object')

# %%
y= crashtypes['Crash_TypeFormated']

# %%
X = crashtypes[['StateFormated', 'DateFormated', 'TimeFormated',
       'Bus_InvolvementFormated', 'Heavy_Rigid_Truck_InvolvementFormated',
       'Speed_LimitFormated', 'Road_UserFormated', 'GenderFormated',
       'AgeFormated']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.coef_
# Out:
# array([  1.38552354e-02,   7.43631968e-07,  -2.14945333e-01,
#         -3.34959644e-01,  -7.86627150e-02,   7.76487817e-04,
#          2.06714956e-02,   1.52437036e-01,  -5.58446262e-03])

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test (True Values)')
plt.ylabel('Predicted Values')
# Out:
# Text(0,0.5,'Predicted Values')

# %%
from sklearn import metrics

# %%
print('MAE', metrics.mean_absolute_error(y_test,predictions))
print('MSE', metrics.mean_squared_error(y_test,predictions))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# MAE 2.03486400366e-15
# MSE 6.95664478283e-30
# RMSE 2.63754521911e-15

# %%
metrics.explained_variance_score(y_test,predictions)
# Out:
# 1.0

# %%
sns.distplot((y_test-predictions),bins=50)

# %%
cdf = pd.DataFrame(lm.coef_,X.columns, columns=['Coeff'])
cdf
# Out:
#                                               Coeff
# StateFormated                         -3.102039e-16
# DateFormated                           0.000000e+00
# TimeFormated                          -8.260670e-16
# Crash_TypeFormated                     1.000000e+00
# Bus_InvolvementFormated                1.202886e-15
# Heavy_Rigid_Truck_InvolvementFormated  5.585235e-16
# Speed_LimitFormated                   -1.856696e-17
# Road_UserFormated                     -1.315481e-16
# GenderFormated                        -8.614502e-16
# AgeFormated                           -2.075887e-17
